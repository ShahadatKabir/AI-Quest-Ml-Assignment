# %% [markdown]
# # Problem Set: Scaling & Linear Regression

# %% [markdown]
# # Part 1: Data Preprocessing

# %% [markdown]
# 1. Load the Excel dataset into a pandas DataFrame. Handle any missing values and perform data
# exploration to understand the characteristics of the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('real estate.csv')

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
missing_values = df.isnull()

# %%
missing_values.head()
# Out:
#       No  X1 transaction date  X2 house age  \
# 0  False                False         False
# 1  False                False         False
# 2  False                False         False
# 3  False                False         False
# 4  False                False         False
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                            False
# 4                                   False                            False
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0        False         False                       False
# 1        False         False                       False
# 2        False         False                       False
# ...

# %%
column_mean=df1.mean()
data_filled=df1.fillna(column_mean)

# %%
data_filled.head() #??
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
drop_row_with_missing_values=df.dropna()

# %%
drop_row_with_missing_values.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df1.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %% [markdown]
# # visualization

# %%
df1.hist(figsize=(10,10))
plt.show()

# %%
sns.pairplot(df1[['No','X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longitude','Y house price of unit area']])

# %%
sns.boxplot(data=df1)
# Out:
# <AxesSubplot:>

# %%
df.nunique()
# Out:
# No                                        414
# X1 transaction date                        12
# X2 house age                              236
# X3 distance to the nearest MRT station    259
# X4 number of convenience stores            11
# X5 latitude                               234
# X6 longitude                              232
# Y house price of unit area                270
# dtype: int64

# %%
'''correlation_matrix=df1.corr()
sns.heatmap(correlation_matrix, annotations =True,color_map='coolwarm')
plt.show()'''
# Out:
# "correlation_matrix=df1.corr()\nsns.heatmap(correlation_matrix, annotations =True,color_map='coolwarm')\nplt.show()"

# %%
correlation_matrix = df1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.countplot(x='X5 latitude',data=df1)
# Out:
# <AxesSubplot:xlabel='X5 latitude', ylabel='count'>

# %% [markdown]
# 2. Extract the feature columns (X1 to X6) and the target column (Y). Split the dataset into features (X) and target (y). (70% training & 30% testng rato).

# %%
df1=df1.rename(columns={'X1 transaction date':'x1 date','X2 house age':'x2 age','X3 distance to the nearest MRT station':'x3 MRT station','X4 number of convenience stores':'x4 number of stores','X5 latitude':'latitude','X6 longitude':'longitude','Y house price of unit area':'y unit price'})

# %%
df1.head()
# Out:
#    No   x1 date  x2 age  x3 MRT station  x4 number of stores  latitude  \
# 0   1  2012.917    32.0        84.87882                   10  24.98298
# 1   2  2012.917    19.5       306.59470                    9  24.98034
# 2   3  2013.583    13.3       561.98450                    5  24.98746
# 3   4  2013.500    13.3       561.98450                    5  24.98746
# 4   5  2012.833     5.0       390.56840                    5  24.97937
#
#    longitude  y unit price
# 0  121.54024          37.9
# 1  121.53951          42.2
# 2  121.54391          47.3
# 3  121.54391          54.8
# 4  121.54245          43.1

# %%
df1=df1.drop('No',axis=1)

# %%
df1.head()
# Out:
#     x1 date  x2 age  x3 MRT station  x4 number of stores  latitude  longitude  \
# 0  2012.917    32.0        84.87882                   10  24.98298  121.54024
# 1  2012.917    19.5       306.59470                    9  24.98034  121.53951
# 2  2013.583    13.3       561.98450                    5  24.98746  121.54391
# 3  2013.500    13.3       561.98450                    5  24.98746  121.54391
# 4  2012.833     5.0       390.56840                    5  24.97937  121.54245
#
#    y unit price
# 0          37.9
# 1          42.2
# 2          47.3
# 3          54.8
# 4          43.1

# %%
x=df1[['x1 date','x2 age','x3 MRT station','x4 number of stores','latitude','longitude']]
y=df1['y unit price']

# %%
x
# Out:
#       x1 date  x2 age  x3 MRT station  x4 number of stores  latitude  \
# 0    2012.917    32.0        84.87882                   10  24.98298
# 1    2012.917    19.5       306.59470                    9  24.98034
# 2    2013.583    13.3       561.98450                    5  24.98746
# 3    2013.500    13.3       561.98450                    5  24.98746
# 4    2012.833     5.0       390.56840                    5  24.97937
# ..        ...     ...             ...                  ...       ...
# 409  2013.000    13.7      4082.01500                    0  24.94155
# 410  2012.667     5.6        90.45606                    9  24.97433
# 411  2013.250    18.8       390.96960                    7  24.97923
# 412  2013.000     8.1       104.81010                    5  24.96674
# 413  2013.500     6.5        90.45606                    9  24.97433
#
#      longitude
# 0    121.54024
# 1    121.53951
# 2    121.54391
# 3    121.54391
# 4    121.54245
# ..         ...
# 409  121.50381
# ...

# %%
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: y unit price, Length: 414, dtype: float64

# %%
#from sklearn.model_selection import train _test_split
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
xtrain.head()
# Out:
#       x1 date  x2 age  x3 MRT station  x4 number of stores  latitude  \
# 7    2013.417    20.3       287.60250                    6  24.98042
# 194  2013.500    15.2      3771.89500                    0  24.93363
# 19   2012.667     1.5        23.38284                    7  24.96772
# 176  2012.833    13.9      4573.77900                    0  24.94867
# 367  2012.833    15.0      1828.31900                    2  24.96464
#
#      longitude
# 7    121.54228
# 194  121.51158
# 19   121.54102
# 176  121.49507
# 367  121.51531

# %%
xtest.head()
# Out:
#       x1 date  x2 age  x3 MRT station  x4 number of stores  latitude  \
# 358  2013.167     1.1        193.5845                    6  24.96571
# 350  2013.000    13.2        492.2313                    5  24.96515
# 373  2013.083     0.0        274.0144                    1  24.97480
# 399  2012.917    12.7        170.1289                    1  24.97371
# 369  2012.667    20.2       2185.1280                    3  24.96322
#
#      longitude
# 358  121.54089
# 350  121.53737
# 373  121.53059
# 399  121.52984
# 369  121.51237

# %%
ytrain.head()
# Out:
# 7      46.7
# 194    29.3
# 19     47.7
# 176    19.2
# 367    20.9
# Name: y unit price, dtype: float64

# %%
ytest.head()
# Out:
# 358    45.1
# 350    42.3
# 373    52.2
# 399    37.3
# 369    22.8
# Name: y unit price, dtype: float64

# %% [markdown]
# 3. Standardize the feature columns (X1 to X6) using Z-score scaling. Implement the scaling process
# manually (without using libraries like `scikit-learn`).

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
for column in x.columns:
    if pd.api.types.is_numeric_dtype(x[column]):
        x[[column]] = scaler.fit_transform(x[[column]])
    else:
        continue
# Out:
# C:\Users\MD SHAHADAT KABIR\AppData\Local\Temp\ipykernel_8968\844835689.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[[column]] = scaler.fit_transform(x[[column]])
# C:\Users\MD SHAHADAT KABIR\AppData\Local\Temp\ipykernel_8968\844835689.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[[column]] = scaler.fit_transform(x[[column]])
# C:\Users\MD SHAHADAT KABIR\AppData\Local\Temp\ipykernel_8968\844835689.py:3: SettingWithCopyWarning:
# ...

# %%
x.head()
# Out:
#     x1 date    x2 age  x3 MRT station  x4 number of stores  latitude  \
# 0 -0.823683  1.255628       -0.792495             2.007407  1.125430
# 1 -0.823683  0.157086       -0.616612             1.667503  0.912444
# 2  1.541151 -0.387791       -0.414015             0.307885  1.486860
# 3  1.246435 -0.387791       -0.414015             0.307885  1.486860
# 4 -1.121951 -1.117223       -0.549997             0.307885  0.834188
#
#    longitude
# 0   0.448762
# 1   0.401139
# 2   0.688183
# 3   0.688183
# 4   0.592937

# %% [markdown]
# # part 2: Linear Regression

# %% [markdown]
# 4. Implement a simple linear regression model using the scaled features (X1 to X6) to predict the house price (Y). You can use gradient descent for optmizaton. Calculate the regression coefcients (intercept and slope) and write down the regression equaton.

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()

# %%
lreg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lreg.coef_
# Out:
# array([ 5.84779706e+00, -2.42545813e-01, -5.13873381e-03,  1.07449530e+00,
#         2.39096949e+02, -5.22351591e+01])

# %%
lreg.intercept_
# Out:
# -11350.7405187715

# %%
y_pred=lreg.predict(xtest)

# %%
y_pred
# Out:
# array([47.55430212, 41.08372744, 44.25551663, 40.51685112, 27.43467608,
#        45.85435624, 44.70296876, 46.57752144, 23.86072119, 54.35199522,
#        34.63011363, 36.34958785, 37.34518438, 23.49428018, 36.02735916,
#        34.56828629, 44.01823263, 45.04246804, 29.9554971 , 43.96338099,
#         0.09450675, 35.291724  , 48.09455663, 45.54503941, 10.6006418 ,
#        39.9786752 , 11.9116313 , 42.79356737, 35.67204264, 38.09573519,
#        12.98819108, 40.13164278, 35.44632378, 27.09263458, 46.57230583,
#        32.08134705, 50.62714445, 13.2533591 , 49.8007962 , 40.83574406,
#        39.02898306, 40.92260381, 47.61743515, 37.68719274, 39.67028734,
#        46.64468542, 43.57375428, 19.40851794, 46.95629589, 45.93056809,
#        48.03966928, 48.79469044, 43.06419598, 43.00021216, 36.56049741,
#        14.20568662, 37.31495695, 34.30916207, 28.33264665, 46.09215428,
#        32.92580137, 32.83028385, 14.20568662,  8.3906898 ,  9.79703308,
# ...

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(ytest,y_pred)

# %%
mse
# Out:
# 73.56837932850405

# %% [markdown]
# 5. Evaluate the model's performance using metrics such as Mean Squared Error (MSE) and R-squared.
# Interpret the R-squared value in the context of this regression.

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(ytest,y_pred)

# %%
r2
# Out:
# 0.5600638168604155

# %% [markdown]
# # Part 3: Feature Scaling Comparison

# %% [markdown]
# 6. Train another linear regression model without scaling the features. Compare the performance of this model with the scaled model from Part 2 in terms of convergence speed and predicton accuracy.

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df2=df2.drop('No',axis=1)

# %%
df2.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
df2_x=df2[['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longitude']]
df2_y=df2['Y house price of unit area']

# %%
df2_x.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245

# %%
df2_y.head()
# Out:
# 0    37.9
# 1    42.2
# 2    47.3
# 3    54.8
# 4    43.1
# Name: Y house price of unit area, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(df2_x,df2_y,test_size=.03,random_state=42)

# %%
x_train.shape
# Out:
# (401, 6)

# %%
x_test.shape
# Out:
# (13, 6)

# %%
from sklearn.linear_model import LinearRegression
reg2=LinearRegression()

# %%
reg2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg2.coef_
# Out:
# array([ 5.21164884e+00, -2.63001526e-01, -4.53447384e-03,  1.13684717e+00,
#         2.18504264e+02, -1.75979489e+01])

# %%
reg2.intercept_
# Out:
# -13766.00465025931

# %%
y_pred2=reg2.predict(x_test)
y_pred2
# Out:
# array([47.81249599, 41.20836129, 43.78253866, 39.82338047, 27.70001691,
#        45.19968334, 44.56659305, 46.22317165, 23.83862057, 54.25682354,
#        33.99952285, 36.41460354, 37.30700143])

# %%
mse2=mean_squared_error(y_test,y_pred2)
mse2
# Out:
# 32.032163249123315

# %%
R2=r2_score(y_test,y_pred2)

# %%
R2
# Out:
# 0.782877735905361

# %% [markdown]
# # Part 4: Visualizaton and Analysis

# %% [markdown]
# 7. Create scater plots to visualize the relatonship between each feature (X1 to X6) and the target
# variable (Y). Discuss the paterns you observe in the plots.

# %%
for i in df2_x:
    plt.figure(figsize=(6,4))
    plt.scatter(df2_x[i],df2['Y house price of unit area']),
    plt.xlabel(i)
    plt.ylabel(i)
    plt.ylabel('Y house price of unit area')
    plt.title(f"scatter plot of {i} vs.{df2_y}")
    plt.show()

# %% [markdown]
# 8. Visualize the predicted house prices from the scaled model against the actual house prices. Interpret the results and discuss any discrepancies.

# %%
plt.figure(figsize=(10,8))
plt.scatter(ytest,y_pred)
plt.plot(ytest,y_pred,color='red')
plt.xlabel('acctual house price')
plt.ylabel('prdicted house prices')
plt.title('visualize the predicted house prices from the scaled model against the house price')
plt.legend
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Part 5: Advanced Problem (Optonal)

# %% [markdown]
# 9. Implement Min-Max scaling for the feature columns (X1 to X6) manually (without using libraries).
# Train a linear regression model using the Min-Max scaled features and compare its performance with the Z-score scaled and unscaled models.

# %%
df2.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
df3=df.copy()

# %%
df3
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
for column in df3.columns:
    column_mean =df3[column].sum()/len(df3[column])
    column_max=df3[column].max()
    column_min=df3[column].min()
    df3[column]=[(value-column_mean)/(column_max-column_min) for value in df3 [column]]

# %%
df3.head()
# Out:
#          No  X1 transaction date  X2 house age  \
# 0 -0.500000            -0.253243      0.326197
# 1 -0.497579            -0.253243      0.040809
# 2 -0.495157             0.473831     -0.100743
# 3 -0.492736             0.383219     -0.100743
# 4 -0.490315            -0.344947     -0.290241
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                               -0.154534                          0.59058
# 1                               -0.120237                          0.49058
# 2                               -0.080732                          0.09058
# 3                               -0.080732                          0.09058
# 4                               -0.107248                          0.09058
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     0.169049      0.074174                   -0.000730
# 1     0.137057      0.066303                    0.038397
# ...

# %%
df4=df3.copy()

# %%
df4
# Out:
#            No  X1 transaction date  X2 house age  \
# 0   -0.500000            -0.253243      0.326197
# 1   -0.497579            -0.253243      0.040809
# 2   -0.495157             0.473831     -0.100743
# 3   -0.492736             0.383219     -0.100743
# 4   -0.490315            -0.344947     -0.290241
# ..        ...                  ...           ...
# 409  0.490315            -0.162632     -0.091611
# 410  0.492736            -0.526169     -0.276542
# 411  0.495157             0.110294      0.024827
# 412  0.497579            -0.162632     -0.219465
# 413  0.500000             0.383219     -0.255995
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                 -0.154534                          0.59058
# 1                                 -0.120237                          0.49058
# 2                                 -0.080732                          0.09058
# ...

# %%
df4=df4.drop('No',axis=1)

# %%
df4.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0            -0.253243      0.326197                               -0.154534
# 1            -0.253243      0.040809                               -0.120237
# 2             0.473831     -0.100743                               -0.080732
# 3             0.383219     -0.100743                               -0.080732
# 4            -0.344947     -0.290241                               -0.107248
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                          0.59058     0.169049      0.074174
# 1                          0.49058     0.137057      0.066303
# 2                          0.09058     0.223339      0.113747
# 3                          0.09058     0.223339      0.113747
# 4                          0.09058     0.125302      0.098004
#
#    Y house price of unit area
# 0                   -0.000730
# 1                    0.038397
# 2                    0.084803
# ...

# %%
df4_x=df[['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longitude']]
df4_y=df['Y house price of unit area']

# %%
df4_x.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()

# %%
for column in df4_x.columns:
    if pd.api.types.is_numeric_dtype(df4_x[column]):
        df4_x[[column]]=m.fit_transform(df4_x[[column]])
    else:
        continue
# Out:
# C:\Users\MD SHAHADAT KABIR\AppData\Local\Temp\ipykernel_8968\3579208930.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_x[[column]]=m.fit_transform(df4_x[[column]])
# C:\Users\MD SHAHADAT KABIR\AppData\Local\Temp\ipykernel_8968\3579208930.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_x[[column]]=m.fit_transform(df4_x[[column]])
# C:\Users\MD SHAHADAT KABIR\AppData\Local\Temp\ipykernel_8968\3579208930.py:3: SettingWithCopyWarning:
# ...

# %%
df4_x.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             0.272926      0.730594                                0.009513
# 1             0.272926      0.445205                                0.043809
# 2             1.000000      0.303653                                0.083315
# 3             0.909389      0.303653                                0.083315
# 4             0.181223      0.114155                                0.056799
#
#    X4 number of convenience stores  X5 latitude  X6 longitude
# 0                              1.0     0.616941      0.719323
# 1                              0.9     0.584949      0.711451
# 2                              0.5     0.671231      0.758896
# 3                              0.5     0.671231      0.758896
# 4                              0.5     0.573194      0.743153

# %%
x_train3,x_test3,y_train3,y_test3 =train_test_split(df4_x,df4_y,test_size=.030,random_state=42)

# %%
x_train3.head()
# Out:
#      X1 transaction date  X2 house age  \
# 55              0.181223      0.723744
# 126             0.454148      0.881279
# 376             0.818777      0.335616
# 56              0.818777      0.767123
# 291             0.181223      0.077626
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 55                                 0.175918                              0.0
# 126                                0.120859                              0.4
# 376                                0.262012                              0.2
# 56                                 0.053811                              0.8
# 291                                0.005119                              0.7
#
#      X5 latitude  X6 longitude
# 55      0.213403      0.609877
# 126     0.561197      0.660341
# 376     0.392632      0.463231
# 56      0.490427      0.723097
# 291     0.307441      0.685573

# %%
from sklearn.linear_model import LinearRegression
reg3=LinearRegression()

# %%
reg3.fit(x_train3,y_train3)
# Out:
# LinearRegression()

# %%
reg3.coef_
# Out:
# array([  4.77387033, -11.51946683, -29.31373259,  11.36847173,
#         18.03097188,  -1.63203378])

# %%
reg3.intercept_
# Out:
# 33.28157958243803
